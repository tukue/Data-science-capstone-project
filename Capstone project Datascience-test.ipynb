# %%
  #  first capstone project
  # notebook url
# https://eu-gb.dataplatform.cloud.ibm.com/analytics/notebooks/v2/835a5a6a-8017-423d-8f3c-fc6f67608a9a/view?access_token=c4dfc62d0dada0a45b814fecd0fe03dd32e009f747499d096fa0aaaa24afe73a

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Hello Capstone Project Course ")
# Out:
# Hello Capstone Project Course
