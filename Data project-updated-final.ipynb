# %% [raw]
# # Define the problem and business idea
# comparing the neighborhood of New York City and Toronto city to see that how multicultural these cities are interms of availability of international resturants and identify cultural places.This will help small and medium business to get summarized data about the neigborhood compostions before starting thier business. For e.g small business that sell specific spice for indian resturant, italian restaurant, french restaurants etc or companies that focus on importing raw materials from other countries to support the multicaltural shops around New york and Toronto will be interested in having this kind of data.

# %% [raw]
# #Foursquare
# Foursquare location data api will be used to explore and compare neighborhoods of cities, to specfically explore different restaurants, bars and cultural parks if they exis
# 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
#             CLIENT_ID,
#             CLIENT_SECRET,
#             VERSION,
#             lat,
#             lng,
#             radius,
#             LIMIT)
#
#   An example data sample that will be used:
#
# https://eu-gb.dataplatform.cloud.ibm.com/analytics/notebooks/v2/3c817844-94aa-4acd-80af-dd8829025961/view?access_token=6d32e159131dc9f342ad82f29feb06cb3227eb64b7b503c6ea934aadbd266c5d
