# %% [raw]
# # Define the problem and business idea
# comparing the neighborhood of New York City and Toronto city to see that how multicultural these cities are interms of availability of international resturants and identify cultural places. This will help startups to get summarized data about the neigborhood compostions before launching thier business.

# %% [raw]
# #Foursquare
# Foursquare location data api will be used to explore and compare neighborhoods of cities.
