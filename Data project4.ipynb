# %% [raw]
# # Define the problem and business idea
# comparing the neighborhood of New York City and Toronto city to see that how multicultural these cities are interms of availability of international resturants and identify cultural places.This will help startups to get summarized data about the neigborhood compostions before launching thier business.For e.g For opening restaurant

# %% [raw]
# #Foursquare
# Foursquare location data api will be used to explore and compare neighborhoods of cities, to specfically explore different restaurants, bars and cultural parks if they exist
# 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
#             CLIENT_ID,
#             CLIENT_SECRET,
#             VERSION,
#             lat,
#             lng,
#             radius,
#             LIMIT)

# %% [raw]
# # New york data
# https://geo.nyu.edu/catalog/nyu_2451_34572
# #Toronto city
# https://geo.nyu.edu/catalog/nyu-2451-36120
